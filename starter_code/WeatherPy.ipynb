# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = weather_api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
units = "metric"
#List of City data
citynamelist = []
cloudinesslist = []
countrylist = []
datelist = []
humiditylist = []
latlist = []
lnglist = []
maxtemplist = []
windspeedlist = []
indexcounter = 0
setcounter = 1

query_url = f"{url}&units={units}&q="
query_url + city
response = requests.get(query_url + city).json()
response
# loop through cities, make API request, and append desired results
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        citynamelist.append(response["name"])
        cloudinesslist.append(response["clouds"]["all"])
        countrylist.append(response["sys"]["country"])
        datelist.append(response["dt"])
        humiditylist.append(response["main"]["humidity"])
        latlist.append(response["coord"]["lat"])
        lnglist.append(response["coord"]["lon"])
        maxtemplist.append(response['main']['temp_max'])
        windspeedlist.append(response["wind"]["speed"])
        if indexcounter > 49:
            indexcounter = 0
            setcounter = setcounter + 1
    
        else:
            indexcounter = indexcounter + 1
            
        print(f"Processing Record {indexcounter} of Set {setcounter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# City not found. Skipping...
# Processing Record 1 of Set 1 : goulburn
# Processing Record 2 of Set 1 : ati
# Processing Record 3 of Set 1 : jatai
# Processing Record 4 of Set 1 : avarua
# Processing Record 5 of Set 1 : yatou
# Processing Record 6 of Set 1 : leningradskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 : hilo
# Processing Record 8 of Set 1 : cape town
# Processing Record 9 of Set 1 : bredasdorp
# Processing Record 10 of Set 1 : la marque
# Processing Record 11 of Set 1 : wonthaggi
# Processing Record 12 of Set 1 : kieta
# Processing Record 13 of Set 1 : jambi
# Processing Record 14 of Set 1 : busselton
# Processing Record 15 of Set 1 : saint-philippe
# Processing Record 16 of Set 1 : grindavik
# Processing Record 17 of Set 1 : punta arenas
# Processing Record 18 of Set 1 : provideniya
# Processing Record 19 of Set 1 : salalah
# City not found. Skipping...
# Processing Record 20 of Set 1 : rafsanjan
# Processing Record 21 of Set 1 : karratha
# Processing Record 22 of Set 1 : albany
# Processing Record 23 of Set 1 : lompoc
# City not found. Skipping...
# Processing Record 24 of Set 1 : quatre cocos
# Processing Record 25 of Set 1 : ushuaia
# Processing Record 26 of Set 1 : san quintin
# Processing Record 27 of Set 1 : saskylakh
# Processing Record 28 of Set 1 : tuktoyaktuk
# Processing Record 29 of Set 1 : biloela
# Processing Record 30 of Set 1 : yellowknife
# City not found. Skipping...
# Processing Record 31 of Set 1 : atuona
# Processing Record 32 of Set 1 : nizhnevartovsk
# Processing Record 33 of Set 1 : el colomo
# Processing Record 34 of Set 1 : silikatnyy
# Processing Record 35 of Set 1 : churachandpur
# Processing Record 36 of Set 1 : kabakovo
# Processing Record 37 of Set 1 : barentu
# Processing Record 38 of Set 1 : east london
# Processing Record 39 of Set 1 : rikitea
# Processing Record 40 of Set 1 : waipawa
# Processing Record 41 of Set 1 : codrington
# City not found. Skipping...
# Processing Record 42 of Set 1 : sabha
# Processing Record 43 of Set 1 : vaini
# Processing Record 44 of Set 1 : bluff
# Processing Record 45 of Set 1 : severo-kurilsk
# Processing Record 46 of Set 1 : gbarnga
# Processing Record 47 of Set 1 : baicheng
# Processing Record 48 of Set 1 : plettenberg bay
# Processing Record 49 of Set 1 : borogontsy
# Processing Record 50 of Set 1 : puerto ayora
# Processing Record 0 of Set 2 : hobart
# City not found. Skipping...
# Processing Record 1 of Set 2 : dubbo
# Processing Record 2 of Set 2 : carnarvon
# Processing Record 3 of Set 2 : barrow
# Processing Record 4 of Set 2 : chastyye
# Processing Record 5 of Set 2 : buala
# Processing Record 6 of Set 2 : kodiak
# Processing Record 7 of Set 2 : champasak
# City not found. Skipping...
# Processing Record 8 of Set 2 : dunedin
# Processing Record 9 of Set 2 : bubaque
# Processing Record 10 of Set 2 : chokurdakh
# Processing Record 11 of Set 2 : hare bay
# Processing Record 12 of Set 2 : maragogi
# Processing Record 13 of Set 2 : gornopravdinsk
# Processing Record 14 of Set 2 : coihaique
# City not found. Skipping...
# Processing Record 15 of Set 2 : rottingdean
# Processing Record 16 of Set 2 : geraldton
# Processing Record 17 of Set 2 : arraial do cabo
# Processing Record 18 of Set 2 : calatayud
# Processing Record 19 of Set 2 : obo
# Processing Record 20 of Set 2 : saint george
# Processing Record 21 of Set 2 : mar del plata
# Processing Record 22 of Set 2 : zhoukou
# Processing Record 23 of Set 2 : maputo
# Processing Record 24 of Set 2 : abha
# Processing Record 25 of Set 2 : zaysan
# Processing Record 26 of Set 2 : dukat
# Processing Record 27 of Set 2 : port lincoln
# Processing Record 28 of Set 2 : limulunga
# Processing Record 29 of Set 2 : padre bernardo
# Processing Record 30 of Set 2 : port alfred
# Processing Record 31 of Set 2 : itarema
# Processing Record 32 of Set 2 : seoul
# Processing Record 33 of Set 2 : kirovskiy
# Processing Record 34 of Set 2 : new norfolk
# City not found. Skipping...
# Processing Record 35 of Set 2 : kapaa
# Processing Record 36 of Set 2 : bontang
# Processing Record 37 of Set 2 : necochea
# Processing Record 38 of Set 2 : jamestown
# Processing Record 39 of Set 2 : wanaka
# Processing Record 40 of Set 2 : dikson
# Processing Record 41 of Set 2 : akureyri
# Processing Record 42 of Set 2 : chipinge
# Processing Record 43 of Set 2 : san carlos de bariloche
# Processing Record 44 of Set 2 : yar-sale
# Processing Record 45 of Set 2 : ponta do sol
# Processing Record 46 of Set 2 : fortuna
# Processing Record 47 of Set 2 : eyl
# Processing Record 48 of Set 2 : pitimbu
# Processing Record 49 of Set 2 : khatanga
# Processing Record 50 of Set 2 : kabinda
# Processing Record 0 of Set 3 : mataura
# Processing Record 1 of Set 3 : hermanus
# Processing Record 2 of Set 3 : yulara
# Processing Record 3 of Set 3 : lagoa
# Processing Record 4 of Set 3 : samarkand
# Processing Record 5 of Set 3 : hithadhoo
# Processing Record 6 of Set 3 : qostanay
# Processing Record 7 of Set 3 : riviere-au-renard
# Processing Record 8 of Set 3 : evensk
# Processing Record 9 of Set 3 : denpasar
# Processing Record 10 of Set 3 : port elizabeth
# Processing Record 11 of Set 3 : hasaki
# Processing Record 12 of Set 3 : hit
# Processing Record 13 of Set 3 : zhuhai
# Processing Record 14 of Set 3 : dingle
# Processing Record 15 of Set 3 : beringovskiy
# Processing Record 16 of Set 3 : airai
# Processing Record 17 of Set 3 : pangnirtung
# Processing Record 18 of Set 3 : qaanaaq
# Processing Record 19 of Set 3 : westport
# Processing Record 20 of Set 3 : mitsamiouli
# Processing Record 21 of Set 3 : klaksvik
# Processing Record 22 of Set 3 : vallenar
# Processing Record 23 of Set 3 : sabang
# Processing Record 24 of Set 3 : saint-joseph
# Processing Record 25 of Set 3 : chuy
# Processing Record 26 of Set 3 : kapoeta
# Processing Record 27 of Set 3 : umba
# Processing Record 28 of Set 3 : adrar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 3 : boguchany
# Processing Record 30 of Set 3 : katsuura
# Processing Record 31 of Set 3 : tasiilaq
# Processing Record 32 of Set 3 : asmara
# Processing Record 33 of Set 3 : merauke
# Processing Record 34 of Set 3 : kaitangata
# Processing Record 35 of Set 3 : almaznyy
# Processing Record 36 of Set 3 : altamont
# Processing Record 37 of Set 3 : manta
# Processing Record 38 of Set 3 : sola
# Processing Record 39 of Set 3 : clyde river
# Processing Record 40 of Set 3 : manggar
# Processing Record 41 of Set 3 : gillette
# Processing Record 42 of Set 3 : thompson
# Processing Record 43 of Set 3 : pedernales
# Processing Record 44 of Set 3 : plast
# City not found. Skipping...
# Processing Record 45 of Set 3 : bud
# Processing Record 46 of Set 3 : tiksi
# Processing Record 47 of Set 3 : bara
# Processing Record 48 of Set 3 : galveston
# Processing Record 49 of Set 3 : bethel
# Processing Record 50 of Set 3 : havre-saint-pierre
# Processing Record 0 of Set 4 : bonavista
# Processing Record 1 of Set 4 : aksu
# Processing Record 2 of Set 4 : cherskiy
# Processing Record 3 of Set 4 : prince rupert
# Processing Record 4 of Set 4 : port-gentil
# Processing Record 5 of Set 4 : padang
# Processing Record 6 of Set 4 : yeppoon
# Processing Record 7 of Set 4 : mayahi
# Processing Record 8 of Set 4 : pangai
# Processing Record 9 of Set 4 : nikolskoye
# City not found. Skipping...
# Processing Record 10 of Set 4 : zlate hory
# Processing Record 11 of Set 4 : nome
# Processing Record 12 of Set 4 : conde
# Processing Record 13 of Set 4 : bengkulu
# Processing Record 14 of Set 4 : castro
# Processing Record 15 of Set 4 : victoria
# Processing Record 16 of Set 4 : honavar
# Processing Record 17 of Set 4 : ariquemes
# Processing Record 18 of Set 4 : cacoal
# City not found. Skipping...
# Processing Record 19 of Set 4 : beira
# Processing Record 20 of Set 4 : manama
# Processing Record 21 of Set 4 : myanaung
# Processing Record 22 of Set 4 : victoria point
# Processing Record 23 of Set 4 : guerrero negro
# Processing Record 24 of Set 4 : mizdah
# Processing Record 25 of Set 4 : san rafael del sur
# Processing Record 26 of Set 4 : souillac
# Processing Record 27 of Set 4 : banda aceh
# Processing Record 28 of Set 4 : mezen
# Processing Record 29 of Set 4 : ribeira grande
# Processing Record 30 of Set 4 : wencheng
# Processing Record 31 of Set 4 : quelimane
# Processing Record 32 of Set 4 : gandiaye
# Processing Record 33 of Set 4 : ilulissat
# Processing Record 34 of Set 4 : sao joao da barra
# Processing Record 35 of Set 4 : tamandare
# City not found. Skipping...
# Processing Record 36 of Set 4 : adre
# Processing Record 37 of Set 4 : umm bab
# Processing Record 38 of Set 4 : aldan
# City not found. Skipping...
# Processing Record 39 of Set 4 : matay
# Processing Record 40 of Set 4 : coquimbo
# Processing Record 41 of Set 4 : havoysund
# Processing Record 42 of Set 4 : bathsheba
# Processing Record 43 of Set 4 : kudligi
# Processing Record 44 of Set 4 : chirongui
# Processing Record 45 of Set 4 : jinchang
# City not found. Skipping...
# Processing Record 46 of Set 4 : kununurra
# City not found. Skipping...
# Processing Record 47 of Set 4 : chateau-thierry
# Processing Record 48 of Set 4 : pevek
# Processing Record 49 of Set 4 : constitucion
# Processing Record 50 of Set 4 : upernavik
# Processing Record 0 of Set 5 : cortez
# Processing Record 1 of Set 5 : itacoatiara
# Processing Record 2 of Set 5 : georgetown
# Processing Record 3 of Set 5 : butaritari
# Processing Record 4 of Set 5 : lebu
# Processing Record 5 of Set 5 : olafsvik
# Processing Record 6 of Set 5 : esperance
# Processing Record 7 of Set 5 : roma
# Processing Record 8 of Set 5 : velsk
# Processing Record 9 of Set 5 : ostrovnoy
# Processing Record 10 of Set 5 : makakilo city
# Processing Record 11 of Set 5 : aklavik
# Processing Record 12 of Set 5 : san cristobal
# Processing Record 13 of Set 5 : weyburn
# Processing Record 14 of Set 5 : naze
# Processing Record 15 of Set 5 : ancud
# City not found. Skipping...
# Processing Record 16 of Set 5 : talnakh
# Processing Record 17 of Set 5 : norman wells
# Processing Record 18 of Set 5 : te anau
# Processing Record 19 of Set 5 : meghri
# Processing Record 20 of Set 5 : sheffield
# Processing Record 21 of Set 5 : hualmay
# Processing Record 22 of Set 5 : galle
# Processing Record 23 of Set 5 : mount isa
# City not found. Skipping...
# Processing Record 24 of Set 5 : marawi
# Processing Record 25 of Set 5 : saint-augustin
# Processing Record 26 of Set 5 : cockburn town
# Processing Record 27 of Set 5 : port hardy
# Processing Record 28 of Set 5 : tulare
# Processing Record 29 of Set 5 : totness
# Processing Record 30 of Set 5 : iroquois falls
# Processing Record 31 of Set 5 : berlevag
# Processing Record 32 of Set 5 : kendari
# Processing Record 33 of Set 5 : avera
# Processing Record 34 of Set 5 : vilhena
# Processing Record 35 of Set 5 : lorengau
# Processing Record 36 of Set 5 : mpika
# Processing Record 37 of Set 5 : tahe
# Processing Record 38 of Set 5 : binabalian
# Processing Record 39 of Set 5 : cidreira
# Processing Record 40 of Set 5 : rio grande
# Processing Record 41 of Set 5 : touros
# Processing Record 42 of Set 5 : calmar
# City not found. Skipping...
# Processing Record 43 of Set 5 : sao jose de piranhas
# Processing Record 44 of Set 5 : raudeberg
# Processing Record 45 of Set 5 : guiglo
# Processing Record 46 of Set 5 : turukhansk
# Processing Record 47 of Set 5 : sistranda
# Processing Record 48 of Set 5 : longyearbyen
# Processing Record 49 of Set 5 : panzhihua
# Processing Record 50 of Set 5 : san angelo
# Processing Record 0 of Set 6 : kabansk
# Processing Record 1 of Set 6 : jurado
# City not found. Skipping...
# Processing Record 2 of Set 6 : riyadh
# Processing Record 3 of Set 6 : san patricio
# Processing Record 4 of Set 6 : martinsville
# Processing Record 5 of Set 6 : gamba
# Processing Record 6 of Set 6 : tautira
# Processing Record 7 of Set 6 : turbat
# Processing Record 8 of Set 6 : narsaq
# Processing Record 9 of Set 6 : berdigestyakh
# Processing Record 10 of Set 6 : kigoma
# Processing Record 11 of Set 6 : nieuw amsterdam
# Processing Record 12 of Set 6 : pisco
# Processing Record 13 of Set 6 : miri
# Processing Record 14 of Set 6 : tilichiki
# Processing Record 15 of Set 6 : uusikaupunki
# Processing Record 16 of Set 6 : cabo san lucas
# Processing Record 17 of Set 6 : taoudenni
# Processing Record 18 of Set 6 : shubarkuduk
# City not found. Skipping...
# Processing Record 19 of Set 6 : jirkov
# Processing Record 20 of Set 6 : zhangjiakou
# Processing Record 21 of Set 6 : new amsterdam
# City not found. Skipping...
# Processing Record 22 of Set 6 : tiznit
# Processing Record 23 of Set 6 : erzin
# Processing Record 24 of Set 6 : hovd
# Processing Record 25 of Set 6 : kalispell
# Processing Record 26 of Set 6 : morondava
# Processing Record 27 of Set 6 : poshekhonye
# Processing Record 28 of Set 6 : puerto colombia
# Processing Record 29 of Set 6 : sembe
# Processing Record 30 of Set 6 : brigantine
# City not found. Skipping...
# Processing Record 31 of Set 6 : nisia floresta
# Processing Record 32 of Set 6 : porto novo
# Processing Record 33 of Set 6 : sao filipe
# Processing Record 34 of Set 6 : farah
# Processing Record 35 of Set 6 : vestmannaeyjar
# Processing Record 36 of Set 6 : sibolga
# Processing Record 37 of Set 6 : hirara
# Processing Record 38 of Set 6 : half moon bay
# Processing Record 39 of Set 6 : inirida
# Processing Record 40 of Set 6 : sorong
# Processing Record 41 of Set 6 : sai buri
# Processing Record 42 of Set 6 : faanui
# Processing Record 43 of Set 6 : urcos
# Processing Record 44 of Set 6 : stromness
# City not found. Skipping...
# Processing Record 45 of Set 6 : alofi
# Processing Record 46 of Set 6 : ceyranbatan
# Processing Record 47 of Set 6 : sakakah
# Processing Record 48 of Set 6 : sindor
# Processing Record 49 of Set 6 : solnechnyy
# Processing Record 50 of Set 6 : jiangyou
# City not found. Skipping...
# Processing Record 0 of Set 7 : pervomayskoye
# Processing Record 1 of Set 7 : trat
# Processing Record 2 of Set 7 : vao
# Processing Record 3 of Set 7 : garowe
# Processing Record 4 of Set 7 : nantucket
# Processing Record 5 of Set 7 : biltine
# Processing Record 6 of Set 7 : catuday
# Processing Record 7 of Set 7 : uyuni
# Processing Record 8 of Set 7 : christchurch
# Processing Record 9 of Set 7 : lima
# Processing Record 10 of Set 7 : qaqortoq
# Processing Record 11 of Set 7 : wodonga
# Processing Record 12 of Set 7 : mahebourg
# Processing Record 13 of Set 7 : antalaha
# Processing Record 14 of Set 7 : masuguru
# Processing Record 15 of Set 7 : noumea
# Processing Record 16 of Set 7 : kruisfontein
# Processing Record 17 of Set 7 : tingo maria
# City not found. Skipping...
# Processing Record 18 of Set 7 : dubinino
# Processing Record 19 of Set 7 : muravlenko
# Processing Record 20 of Set 7 : biak
# Processing Record 21 of Set 7 : ambilobe
# Processing Record 22 of Set 7 : torbay
# Processing Record 23 of Set 7 : brae
# Processing Record 24 of Set 7 : kuytun
# Processing Record 25 of Set 7 : hofn
# Processing Record 26 of Set 7 : bichura
# Processing Record 27 of Set 7 : nyazepetrovsk
# Processing Record 28 of Set 7 : grasse
# Processing Record 29 of Set 7 : acarau
# Processing Record 30 of Set 7 : balikpapan
# Processing Record 31 of Set 7 : zemio
# Processing Record 32 of Set 7 : stara synyava
# Processing Record 33 of Set 7 : pacific grove
# Processing Record 34 of Set 7 : maniitsoq
# Processing Record 35 of Set 7 : popondetta
# Processing Record 36 of Set 7 : knysna
# Processing Record 37 of Set 7 : bandarbeyla
# Processing Record 38 of Set 7 : nalut
# Processing Record 39 of Set 7 : maarianhamina
# Processing Record 40 of Set 7 : vardo
# Processing Record 41 of Set 7 : gombong
# Processing Record 42 of Set 7 : zhezkazgan
# Processing Record 43 of Set 7 : leshukonskoye
# Processing Record 44 of Set 7 : itaituba
# Processing Record 45 of Set 7 : lavrentiya
# Processing Record 46 of Set 7 : bambous virieux
# Processing Record 47 of Set 7 : sitka
# Processing Record 48 of Set 7 : thinadhoo
# Processing Record 49 of Set 7 : atbasar
# Processing Record 50 of Set 7 : barao de melgaco
# Processing Record 0 of Set 8 : warmbad
# Processing Record 1 of Set 8 : najran
# Processing Record 2 of Set 8 : trebinje
# Processing Record 3 of Set 8 : ixtapa
# Processing Record 4 of Set 8 : petropavlovsk-kamchatskiy
# Processing Record 5 of Set 8 : tulun
# Processing Record 6 of Set 8 : richards bay
# Processing Record 7 of Set 8 : ukiah
# Processing Record 8 of Set 8 : namatanai
# Processing Record 9 of Set 8 : haines junction
# Processing Record 10 of Set 8 : les ponts-de-ce
# Processing Record 11 of Set 8 : watsa
# City not found. Skipping...
# Processing Record 12 of Set 8 : road town
# Processing Record 13 of Set 8 : sinnamary
# Processing Record 14 of Set 8 : am timan
# Processing Record 15 of Set 8 : kayasula
# Processing Record 16 of Set 8 : adet
# Processing Record 17 of Set 8 : college
# Processing Record 18 of Set 8 : saint-pierre
# Processing Record 19 of Set 8 : praia da vitoria
# Processing Record 20 of Set 8 : bilma
# Processing Record 21 of Set 8 : margate
# Processing Record 22 of Set 8 : harboore
# Processing Record 23 of Set 8 : cottonwood
# Processing Record 24 of Set 8 : chabahar
# Processing Record 25 of Set 8 : nizhniy kuranakh
# City not found. Skipping...
# Processing Record 26 of Set 8 : ahmadnagar
# Processing Record 27 of Set 8 : blagoyevo
# Processing Record 28 of Set 8 : bela
# Processing Record 29 of Set 8 : atar
# Processing Record 30 of Set 8 : bismarck
# Processing Record 31 of Set 8 : valentin gomez farias
# Processing Record 32 of Set 8 : baruun-urt
# Processing Record 33 of Set 8 : along
# Processing Record 34 of Set 8 : rauma
# Processing Record 35 of Set 8 : letlhakane
# Processing Record 36 of Set 8 : nhulunbuy
# Processing Record 37 of Set 8 : tura
# Processing Record 38 of Set 8 : tazovskiy
# Processing Record 39 of Set 8 : monrovia
# Processing Record 40 of Set 8 : kashan
# Processing Record 41 of Set 8 : yenotayevka
# Processing Record 42 of Set 8 : falesti
# Processing Record 43 of Set 8 : dalmau
# City not found. Skipping...
# Processing Record 44 of Set 8 : gasa
# Processing Record 45 of Set 8 : tomatlan
# Processing Record 46 of Set 8 : caraquet
# Processing Record 47 of Set 8 : tarko-sale
# Processing Record 48 of Set 8 : podor
# Processing Record 49 of Set 8 : nyurba
# Processing Record 50 of Set 8 : korla
# Processing Record 0 of Set 9 : ust-ishim
# City not found. Skipping...
# Processing Record 1 of Set 9 : meulaboh
# Processing Record 2 of Set 9 : belyy yar
# Processing Record 3 of Set 9 : bogatyye saby
# Processing Record 4 of Set 9 : roald
# Processing Record 5 of Set 9 : port blair
# Processing Record 6 of Set 9 : pocone
# Processing Record 7 of Set 9 : tambura
# Processing Record 8 of Set 9 : arman
# Processing Record 9 of Set 9 : pavlodar
# City not found. Skipping...
# Processing Record 10 of Set 9 : seljord
# Processing Record 11 of Set 9 : klyuchi
# Processing Record 12 of Set 9 : kalianget
# City not found. Skipping...
# Processing Record 13 of Set 9 : halifax
# Processing Record 14 of Set 9 : buraydah
# Processing Record 15 of Set 9 : kharan
# Processing Record 16 of Set 9 : kirakira
# Processing Record 17 of Set 9 : imeni poliny osipenko
# Processing Record 18 of Set 9 : kundiawa
# Processing Record 19 of Set 9 : leogane
# Processing Record 20 of Set 9 : saint andrews
# Processing Record 21 of Set 9 : auki
# Processing Record 22 of Set 9 : dobre miasto
# Processing Record 23 of Set 9 : abu samrah
# City not found. Skipping...
# Processing Record 24 of Set 9 : sao jose da coroa grande
# Processing Record 25 of Set 9 : coari
# Processing Record 26 of Set 9 : lohja
# Processing Record 27 of Set 9 : corbelia
# Processing Record 28 of Set 9 : charters towers
# Processing Record 29 of Set 9 : yuryev-polskiy
# Processing Record 30 of Set 9 : kattivakkam
# Processing Record 31 of Set 9 : staryy nadym
# Processing Record 32 of Set 9 : lata
# Processing Record 33 of Set 9 : aleksandrov gay
# City not found. Skipping...
# Processing Record 34 of Set 9 : asfi
# Processing Record 35 of Set 9 : kavaratti
# Processing Record 36 of Set 9 : whitehorse
# Processing Record 37 of Set 9 : dakar
# Processing Record 38 of Set 9 : guaimaro
# Processing Record 39 of Set 9 : bonga
# Processing Record 40 of Set 9 : cerrito
# Processing Record 41 of Set 9 : satis
# Processing Record 42 of Set 9 : otjiwarongo
# Processing Record 43 of Set 9 : vanimo
# City not found. Skipping...
# Processing Record 44 of Set 9 : ha giang
# Processing Record 45 of Set 9 : namibe
# Processing Record 46 of Set 9 : acapulco
# Processing Record 47 of Set 9 : iqaluit
# Processing Record 48 of Set 9 : yangambi
# Processing Record 49 of Set 9 : la rioja
# Processing Record 50 of Set 9 : monte patria
# Processing Record 0 of Set 10 : kangaatsiaq
# Processing Record 1 of Set 10 : maceio
# Processing Record 2 of Set 10 : asau
# Processing Record 3 of Set 10 : flinders
# Processing Record 4 of Set 10 : tambovka
# Processing Record 5 of Set 10 : dolores
# Processing Record 6 of Set 10 : takoradi
# Processing Record 7 of Set 10 : sainte-rose
# Processing Record 8 of Set 10 : dajabon
# Processing Record 9 of Set 10 : aykhal
# Processing Record 10 of Set 10 : cabedelo
# Processing Record 11 of Set 10 : bridlington
# Processing Record 12 of Set 10 : kijang
# Processing Record 13 of Set 10 : chernyshevskiy
# Processing Record 14 of Set 10 : nanortalik
# Processing Record 15 of Set 10 : muroto
# Processing Record 16 of Set 10 : sarakhs
# Processing Record 17 of Set 10 : honiara
# City not found. Skipping...
# Processing Record 18 of Set 10 : lwowek slaski
# City not found. Skipping...
# Processing Record 19 of Set 10 : caravelas
# Processing Record 20 of Set 10 : emilio carranza
# Processing Record 21 of Set 10 : mtwango
# Processing Record 22 of Set 10 : aquitania
# Processing Record 23 of Set 10 : walvis bay
# Processing Record 24 of Set 10 : san joaquin
# Processing Record 25 of Set 10 : asyut
# Processing Record 26 of Set 10 : erenhot
# Processing Record 27 of Set 10 : agadez
# Processing Record 28 of Set 10 : ponta delgada
# Processing Record 29 of Set 10 : byron bay
# Processing Record 30 of Set 10 : ocos
# Processing Record 31 of Set 10 : santa eulalia
# Processing Record 32 of Set 10 : colon
# Processing Record 33 of Set 10 : praia
# Processing Record 34 of Set 10 : andapa
# Processing Record 35 of Set 10 : pombas
# Processing Record 36 of Set 10 : isangel
# Processing Record 37 of Set 10 : dhari
# Processing Record 38 of Set 10 : dukstas
# Processing Record 39 of Set 10 : portneuf
# Processing Record 40 of Set 10 : champerico
# Processing Record 41 of Set 10 : rupert
# Processing Record 42 of Set 10 : nishihara
# Processing Record 43 of Set 10 : palu
# Processing Record 44 of Set 10 : saint anthony
# Processing Record 45 of Set 10 : saint-francois
# Processing Record 46 of Set 10 : poum
# Processing Record 47 of Set 10 : muros
# Processing Record 48 of Set 10 : broken hill
# Processing Record 49 of Set 10 : williams lake
# Processing Record 50 of Set 10 : ca mau
# Processing Record 0 of Set 11 : batsfjord
# Processing Record 1 of Set 11 : baykit
# Processing Record 2 of Set 11 : san borja
# Processing Record 3 of Set 11 : bintulu
# City not found. Skipping...
# Processing Record 4 of Set 11 : consett
# Processing Record 5 of Set 11 : novyy urengoy
# Processing Record 6 of Set 11 : palana
# Processing Record 7 of Set 11 : traverse city
# Processing Record 8 of Set 11 : saldanha
# Processing Record 9 of Set 11 : port-cartier
# Processing Record 10 of Set 11 : faya
# Processing Record 11 of Set 11 : pesochnoye
# Processing Record 12 of Set 11 : anadyr
# Processing Record 13 of Set 11 : midyat
# Processing Record 14 of Set 11 : parana
# City not found. Skipping...
# Processing Record 15 of Set 11 : lekoni
# Processing Record 16 of Set 11 : broome
# Processing Record 17 of Set 11 : teguise
# Processing Record 18 of Set 11 : llanes
# Processing Record 19 of Set 11 : hamilton
# Processing Record 20 of Set 11 : atlantic city
# Processing Record 21 of Set 11 : grand forks
# City not found. Skipping...
# Processing Record 22 of Set 11 : kyra
# Processing Record 23 of Set 11 : fuchu
# Processing Record 24 of Set 11 : sinop
# Processing Record 25 of Set 11 : akhtanizovskaya
# Processing Record 26 of Set 11 : plainview
# Processing Record 27 of Set 11 : chernyanka
# Processing Record 28 of Set 11 : itoman
# Processing Record 29 of Set 11 : puerto suarez
# Processing Record 30 of Set 11 : smithers
# Processing Record 31 of Set 11 : usinsk
# Processing Record 32 of Set 11 : palmer
# Processing Record 33 of Set 11 : ewa beach
# Processing Record 34 of Set 11 : dali
# Processing Record 35 of Set 11 : lagunas
# Processing Record 36 of Set 11 : kalabo
# Processing Record 37 of Set 11 : rennes
# Processing Record 38 of Set 11 : jacmel
# Processing Record 39 of Set 11 : krasnovishersk
# Processing Record 40 of Set 11 : kautokeino
# Processing Record 41 of Set 11 : danielskuil
# Processing Record 42 of Set 11 : south lake tahoe
# Processing Record 43 of Set 11 : lasa
# Processing Record 44 of Set 11 : floyita
# Processing Record 45 of Set 11 : nanakuli
# Processing Record 46 of Set 11 : moengo
# City not found. Skipping...
# Processing Record 47 of Set 11 : longford
# Processing Record 48 of Set 11 : beloha
# Processing Record 49 of Set 11 : morro bay
# Processing Record 50 of Set 11 : chunoyar
# Processing Record 0 of Set 12 : mitu
# Processing Record 1 of Set 12 : ngunguru
# Processing Record 2 of Set 12 : sampit
# Processing Record 3 of Set 12 : hammerfest
# Processing Record 4 of Set 12 : orichi
# Processing Record 5 of Set 12 : aviles
# Processing Record 6 of Set 12 : marzuq
# Processing Record 7 of Set 12 : rawson
# Processing Record 8 of Set 12 : bambanglipuro
# Processing Record 9 of Set 12 : taonan
# City not found. Skipping...
# Processing Record 10 of Set 12 : boa vista
# Processing Record 11 of Set 12 : gayny
# Processing Record 12 of Set 12 : kristianstad
# Processing Record 13 of Set 12 : bargur
# Processing Record 14 of Set 12 : novopokrovka
# Processing Record 15 of Set 12 : rio gallegos
# Processing Record 16 of Set 12 : alto araguaia
# Processing Record 17 of Set 12 : trelew
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = pd.DataFrame({ 
                "City" : citynamelist,
                "Cloudiness" : cloudinesslist,
                "Country" : countrylist,
                "Date" : datelist,
                "Humidity" : humiditylist,
                "Lat" : latlist,
                "Lng" : lnglist,
                "Max Temp" : maxtemplist,
                "Wind Speed" : windspeedlist
})

# %%
weather_dict.count()
# Out:
# City          578
# Cloudiness    578
# Country       578
# Date          578
# Humidity      578
# Lat           578
# Lng           578
# Max Temp      578
# Wind Speed    578
# dtype: int64

# %%
weather_dict.head()
# Out:
#        City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Goulburn          42      AU  1592233544        95 -34.75  149.72
# 1       Ati          33      TD  1592233732        14  13.22   18.34
# 2     Jatai           0      BR  1592233732        47 -17.88  -51.71
# 3    Avarua          90      CK  1592233188        77 -21.21 -159.78
# 4     Yatou         100      CN  1592233732        50  37.15  122.38
#
#    Max Temp  Wind Speed
# 0     46.99        8.97
# 1    107.83        4.38
# 2     77.90       13.06
# 3     69.80       11.41
# 4     70.57        3.04

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Temperature (06/15/20)")
plt.xlabel("Laitude")
plt.ylabel("Temperature (F)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)
plt.savefig("../Images/City Latitude vs Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Humidity (06/14/20)")

plt.xlabel("Laitude")

plt.ylabel("Humidity (%)")

plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

plt.savefig("../Images/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Cloudiness (06/14/20)")

plt.xlabel("Laitude")

plt.ylabel("Cloudiness (%)")

plt.ylim(-5,105)

plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Wind Speed (mph) (06/14/20)")

plt.xlabel("Latitude")

plt.ylabel("Wind Speed (%)")

plt.ylim(-2,50)

plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

plt.savefig("../Images/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]

# %%
from scipy import stats
def linear_agression(x,y):
    print(f"The r-squared is : {round(stats.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])
annotate(equation, 0, 0)

plt.title("Northern Hemisphere - Temp vs. Latitude Linear Regression")

plt.xlabel("Latitude")

plt.ylabel("Temp (F)")

plt.savefig("../Images/Northern Hemisphere - Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.72

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Max Temp"])
annotate(equation, -30, 50)
plt.title("Southern Hemisphere - Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Temp (F)")
plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.85

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])
annotate(equation, 40, 15)
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.02

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])
annotate(equation, -40, 50)
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.05

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])
annotate(equation, 30, 40)
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.02

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])
annotate(equation, -30, 40)
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.08

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])
annotate(equation, 40, 20)
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.07

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])
annotate(equation, -30, 15)
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.08
